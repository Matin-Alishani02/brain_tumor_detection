# %% [markdown]
# Import libraries

# %%
import cv2 
import numpy as np 
from keras.models import load_model
from PIL import Image

# %% [markdown]
# Loading model

# %%
model = load_model("brainTumore.h4")

# %% [markdown]
# Preparing input data for prediction

# %%
test_image = cv2.imread("pred\\pred41.jpg")

# %%
test_image = Image.fromarray(test_image)

# %%
test_image
# Out:
# <PIL.Image.Image image mode=RGB size=232x217>

# %%
test_image = test_image.resize((64,64))

# %%
test_image = np.array(test_image)

# %%
test_image = np.expand_dims(test_image,axis=0)

# %% [markdown]
# Prediction

# %%
prediction = np.argmax(model.predict(test_image),axis=1)
# Out:
# 1/1 [==============================] - 0s 343ms/step

# %%
if prediction[0] == 0 :
    print ("You do not a tumor.")
else:
    print ("You have a tumor!")
# Out:
# You do not a tumor.
